# %%
import pandas as pd
df = pd.read_csv('cleaned_hr_data.csv')
df.head()
# Out:
#    Age  Attrition  DailyRate  DistanceFromHome  Education  \
# 0   41          1       1102                 1          2
# 1   49          0        279                 8          1
# 2   37          1       1373                 2          2
# 3   33          0       1392                 3          4
# 4   27          0        591                 2          1
#
#    EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2          94               3         2
# 1                        3          61               2         2
# 2                        4          92               2         1
# 3                        4          56               3         1
# 4                        1          40               3         1
#
#    JobSatisfaction  ...  JobRole_Sales Executive  \
# 0                4  ...                     True
# 1                2  ...                    False
# 2                3  ...                    False
# 3                3  ...                    False
# 4                2  ...                    False
#
#    JobRole_Sales Representative  MaritalStatus_Married  MaritalStatus_Single  \
# 0                         False                  False                  True
# 1                         False                   True                 False
# 2                         False                  False                  True
# 3                         False                   True                 False
# 4                         False                   True                 False
#
#    OverTime_Yes  PromotionGap  StagnancyIndex  SatisfactionScore  \
# 0          True             6        5.000000           2.333333
# 1         False             9        7.666667           3.000000
# 2          True             0        0.000000           3.000000
# 3          True             5        4.000000           3.333333
# 4         False             0        1.333333           2.333333
#
#    IncomePerYear  IsOverworked
# 0     665.888889             0
# 1     466.363636             0
# 2     261.250000             0
# 3     323.222222             1
# 4     495.428571             0
#
# [5 rows x 50 columns]

# %%
from sklearn.model_selection import train_test_split
X = df.drop(['Attrition'], axis=1)
y = df['Attrition']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y)

# %%
from sklearn.tree import DecisionTreeClassifier
dt_model = DecisionTreeClassifier(max_depth=5, random_state=42)
dt_model.fit(X_train, y_train)
y_pred = dt_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

print("Accuracy:", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall:", recall_score(y_test, y_pred))
print("F1 Score:", f1_score(y_test, y_pred))

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# Accuracy: 0.8095238095238095
# Precision: 0.37142857142857144
# Recall: 0.2765957446808511
# F1 Score: 0.3170731707317073
